# %% [markdown]
# # **Importing Files and Basic Plotting**
#
# You can treat this program as a magic box at first if you like, but I will describe what is going on as well.
#
# You will need to save this program in the same directory as your text file containing the data you want to plot,
#
# or you will have to specify the full path to your data.

# %%
# imports important packages similar to "#include" in C
import numpy as np #this has useful data structures like arrays which will be discussed more later
from matplotlib import pyplot as plt #this is for plotting nicely

# This will import the data we exported from C
# in the place of "trajectory.txt" you should use your the name you gave your text file containing
# the "data" from your simulation, which can be the full path if you do not want to store the data 
# in the same directory as this program.
trajectory = np.loadtxt("Hagrid")

# %%
# since we don't know how this was imported, I will just check by asking the program to tell me the 
# dimensions of trajectory
print ("number of dimensions: ",trajectory.ndim)
print ("shape: ", trajectory.shape)
# Out:
# number of dimensions:  2
# shape:  (1002, 2)

# %% [markdown]
# # Comprehension Check
# What do you think this array looks like if you were to draw it out like a data table?
#
# How many rows and columns does it have?
#
# What information do you think is inside each?

# %%
# Now we know how the array "trajectory" is shaped, so we can plot the trajectory!
# If the axes come out inverted, you can always switch the contents in the plot function
plt.plot(trajectory[:,0], trajectory[:,1]);

# %% [markdown]
# This looks about right, but the plot is missing a lot of important details.
#
# Plots should always contain axis labels with proper units!!

# %%
# This cell adds axis labels and units
plt.plot(trajectory[:,0], trajectory[:,1])
plt.xlabel("time (s)");
plt.ylabel("ball height (m)");

# %% [markdown]
# If we were plotting multiple trajectories on one image, a legend might be necessary.
#
# What is a "good" label for this? It should be physically meaningful if possible.
#
# I also like purple, so I am going to make my line purple.

# %%
plt.plot(trajectory[:,0], trajectory[:,1], color = 'purple', label = "Initial Velocity = 12 m/s")
plt.xlabel("time (s)");
plt.ylabel("ball height (m)");
plt.legend(loc='lower left');

# %% [markdown]
# # Comprehension Check:
# Inspect the above code and see if you can guess what each line is doing and answer the following questions:
# 1. Where in the above code tells it to make the line purple? How do you think you would make the color orange?
# 2. What command introduces the legend? Where does the legend appear on the graph? Can you guess how you might make it appear on the upper right?
# 3. Can you switch the axes so it plots time v.s. height?
#
# # **Now it is your turn! In the next cell, customize the plot**
# Using google, find the commands to change the line color, font size, add data point markers, etc. Play with the settings as much as you like.
#
# Other ideas exploring the data and making your plot more useful:
# 1. Figure out how to compute the maximum value inside an array, and then show it on the plot.
# 2. Find where the ball would be below the ground, and don't plot any of those points.

# %%
plt.plot(trajectory[:,0], trajectory[:,1], color = 'purple', label = "Initial Velocity = 12 m/s")
plt.xlabel("time (s)");
plt.ylabel("ball height (m)");
plt.legend(loc='lower left');

# %% [markdown]
# # When you finish playing with this plot:
#
# 1. Go back to lab 4 and generate more "data sets".
#
# 2. Copy, paste and modify code from above into a new cell below to import and plot your new data!
